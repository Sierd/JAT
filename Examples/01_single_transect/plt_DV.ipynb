# %%
# open pickle file an plot the content
import pickle
import matplotlib.pyplot as plt

# open the pickle file
with open(r'C:\Users\svries\Documents\GitHub\JAT\Examples\02_region_transects\D_dataframes_per_dimension\DuneVol_fix_dataframe.pickle', 'rb') as f:
    DV_data = pickle.load(f)

with open(r'C:\Users\svries\Documents\GitHub\JAT\Examples\02_region_transects\A_elevation_dataframes\8008000_elevation.pickle', 'rb') as f:
    E_data = pickle.load(f)

# plot data in frame
fig, ax = plt.subplots(1,2,figsize=(14, 5))





# plot the data
ax[0].plot(E_data.columns, E_data[(E_data!=-9999)].transpose(), 'o')
#set xlim
# ax[0].set_xlim([-200, 250])
# make legend
ax[0].legend(E_data.index)
# ylabel dune volume
#ax[0].set_ylabel('Dune volume [m³/m]')

# plot the data
ax[1].plot(DV_data.index, DV_data, 'o')
# make legend
ax[1].legend(DV_data.columns)
# ylabel dune volume
ax[1].set_ylabel('Dune volume [m³/m]')
plt.show()

# %%
E_data[(E_data!=-9999)]
# Out:
#      -3000.0 -2995.0 -2990.0 -2985.0 -2980.0 -2975.0 -2970.0 -2965.0 -2960.0  \
# 1965     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1966     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1967     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1968     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1969     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1970     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1971     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1972     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1973     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1974     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1975     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
#display data columns
print(data)
# Out:
#            8009325     8009350
# years
# 1965           NaN         NaN
# 1966           NaN         NaN
# 1967           NaN         NaN
# 1968           NaN         NaN
# 1969           NaN         NaN
# 1970           NaN         NaN
# 1971           NaN         NaN
# 1972           NaN         NaN
# 1973           NaN         NaN
# 1974           NaN         NaN
# 1975    636.404167  308.250000
# 1976           NaN  279.316667
# 1977    638.600000  301.654167
# 1978    647.766667  293.750000
# 1979    618.416667  313.016667
# 1980    687.983333  295.395833
# 1981    614.004167  307.191667
# 1982    684.866667  292.883333
# 1983    619.366667  326.908333
# 1984    674.733333  292.320833
# 1985    703.737500  314.916667
# 1986    699.483333  310.812500
# 1987    671.670833  331.037500
# 1988    685.887500  323.166667
# 1989    732.191667  322.833333
# 1990    695.700000  303.170833
# 1991    736.616667  302.100000
# 1992    726.666667  330.187500
# 1993    690.750000  326.316667
# ...
